# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
test_no=1

df1 = pd.read_csv("Time_feature_matrix_bearing_1_Test_ {}.csv".format(test_no),index_col='Unnamed: 0')
df2 = pd.read_csv("Time_feature_matrix_bearing_2_Test_ {}.csv".format(test_no),index_col='Unnamed: 0')
df3 = pd.read_csv("Time_feature_matrix_bearing_3_Test_ {}.csv".format(test_no),index_col='Unnamed: 0')
df4 = pd.read_csv("Time_feature_matrix_bearing_4_Test_ {}.csv".format(test_no),index_col='Unnamed: 0')

df1.index = pd.to_datetime(df1.index)
df2.index = pd.to_datetime(df2.index)
df3.index = pd.to_datetime(df3.index)
df4.index = pd.to_datetime(df4.index)

# %%
plt.bar(df3.index, df3['Min'])
plt.bar(df4.index, df4['Min'])
# Out:
# <BarContainer object of 2156 artists>

# %%
# ----------------- df = pd.DataFrame(data = , index = , columns = [''])
# ------------------S = pd.Series()------------------------------------

# %%
df_norm = pd.read_csv('Normal_Bearing.csv')
df_orf_2 = pd.read_csv('outer_race_fault_test_2.csv')
df_orf_3 = pd.read_csv('outer_race_fault_test_3.csv')
df_irf = pd.read_csv('inner_race_fault.csv')
df_ref = pd.read_csv('roller_element_fault.csv')

# %%
plt.bar(df_irf.index, df_irf['Min'])
plt.bar(df_ref.index, df_ref['Min'])
# Out:
# <BarContainer object of 465 artists>

# %%
plt.scatter(df_irf.index, df_irf['Min'])
plt.scatter(df_ref.index, df_ref['Min'])

# %%
plt.bar(df_irf.index, df_irf['Max'])
plt.bar(df_ref.index, df_ref['Max'])
# Out:
# <BarContainer object of 465 artists>

# %%
plt.scatter(df_irf.index, df_irf['Max'])
plt.scatter(df_ref.index, df_ref['Max'])

# %%
plt.bar(df_irf.index, df_irf['Kurtosis'])
plt.bar(df_ref.index, df_ref['Kurtosis'])
# Out:
# <BarContainer object of 465 artists>

# %%
plt.scatter(df_irf.index, df_irf['Kurtosis'])
plt.scatter(df_ref.index, df_ref['Kurtosis'])

# %%
plt.hist(x, bins=25, color='green', edgecolor='blue',
         linestyle='--', alpha=0.5)
