# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy.io

# %%
file_path = "C:\\Users\\Saranya.Sakkarapani\\Bearing_data\\1st_test\\1st_test"
file_name = '2003.10.22.12.06.13'

# %%
dataset = pd.read_csv(os.path.join(file_path, file_name),sep = '\t',header=None)

# %%
data = pd.DataFrame()

# %%
data = data.append(dataset)
# Out:
# C:\Users\Saranya.Sakkarapani\AppData\Local\Temp\ipykernel_8036\1265051679.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(dataset)

# %%
data.columns = ['1_a','1_b','2_a','2_b','3_a','3_b','4_a','4_b']

# %%
data
# Out:
#          1_a    1_b    2_a    2_b    3_a    3_b    4_a    4_b
# 0     -0.022 -0.039 -0.183 -0.054 -0.105 -0.134 -0.129 -0.142
# 1     -0.105 -0.017 -0.164 -0.183 -0.049  0.029 -0.115 -0.122
# 2     -0.183 -0.098 -0.195 -0.125 -0.005 -0.007 -0.171 -0.071
# 3     -0.178 -0.161 -0.159 -0.178 -0.100 -0.115 -0.112 -0.078
# 4     -0.208 -0.129 -0.261 -0.098 -0.151 -0.205 -0.063 -0.066
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 20475 -0.022 -0.142  0.085 -0.078 -0.200 -0.198 -0.134 -0.093
# 20476  0.024 -0.156  0.042 -0.039 -0.159 -0.071 -0.227 -0.132
# 20477 -0.193 -0.303 -0.071 -0.125 -0.237 -0.251 -0.151  0.007
# 20478 -0.115  0.076 -0.078 -0.332 -0.027 -0.002 -0.151 -0.005
# 20479 -0.042  0.098  0.103 -0.059 -0.002 -0.342 -0.095 -0.276
#
# [20480 rows x 8 columns]

# %%
bearing_no = 0
bearing_data = np.array(data.iloc[:,bearing_no])

# %%
bearing_data
# Out:
# array([-0.022, -0.105, -0.183, ..., -0.193, -0.115, -0.042])

# %%
temp = bearing_data

# %%
# feature extraction
feature_matrix = np.zeros((1,9))

# %%
def skew(x):
    
    n = len(x)
    third_moment = np.sum((x-np.mean(x))**3)/n
    s_3 = np.std(x, ddof = 1) ** 3
    return third_moment / s_3

# %%
def kurtosis(x):
    
    n = len(x)
    fourth_moment = np.sum((x-np.mean(x))**4) / n
    s_4 = np.std(x, ddof = 1) ** 4
    return fourth_moment / s_4 - 3

# %%
feature_matrix[0,0] = np.max(temp)
feature_matrix[0,1] = np.min(temp)
feature_matrix[0,2] = np.mean(temp)
feature_matrix[0,3] = np.std(temp, ddof = 1)
feature_matrix[0,4] = np.sqrt(np.mean(temp ** 2))
feature_matrix[0,5] = skew(temp)
feature_matrix[0,6] = kurtosis(temp)
feature_matrix[0,7] = feature_matrix[0,0]/feature_matrix[0,4]
feature_matrix[0,8] = feature_matrix[0,4]/feature_matrix[0,2]

# %%
# df = pd.DataFrame(feature_matrix)
df.index = [file_name[:-3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # df = pd.DataFrame(feature_matrix)
# ----> 2 df.index = [file_name[:-3]]
#
# NameError: name 'df' is not defined

# %%
df

# %%
file_path = "C:\\Users\\Saranya.Sakkarapani\\Bearing_data\\1st_test\\1st_test"
file_name = '2003.10.22.12.06.13'

# %%
time_features = ['Max','Min','Mean','Std','RMS','Skewness','Kurtosis','Crestfactor','Formfactor']
cols = ['1_a','1_b','2_a','2_b','3_a','3_b','4_a','4_b']
   
columns = [c+'_'+tf for c in cols for tf in time_features]
data = pd.DataFrame(columns=columns)
# data.index = [file_name[:-3]]
    
for file_name in os.listdir(file_path):
    
    # read dataset
    raw_data = pd.read_csv(os.path.join(file_path, file_name), sep='\t')      
    
    
    
    # time features
    Max = np.array(np.max(raw_data))
    Min = np.array(raw_data.min())
    Mean = np.array(raw_data.mean())
    Std = np.array(np.std(raw_data, ddof = 1))
    RMS = np.array(np.sqrt(np.mean(raw_data**2)))
    Skewness = np.array(skew(raw_data))
    Kurtosis = np.array(kurtosis(raw_data))
    Crestfactor = np.array(Max/RMS)
    Formfactor = np.array(RMS/Mean)
        
    
#     # time features
#     feature_matrix[0,0] = np.max(temp)
#     feature_matrix[0,1] = np.min(temp)
#     feature_matrix[0,2] = np.mean(temp)
#     feature_matrix[0,3] = np.std(temp, ddof = 1)
#     feature_matrix[0,4] = np.sqrt(np.mean(temp ** 2))
#     feature_matrix[0,5] = skew(temp)
#     feature_matrix[0,6] = kurtosis(temp)
#     feature_matrix[0,7] = feature_matrix[0,0]/feature_matrix[0,4]
#     feature_matrix[0,8] = feature_matrix[0,4]/feature_matrix[0,2]
        
        
    Max = pd.DataFrame(Max.reshape(1,8), columns=[c+'_Max' for c in cols])
    Min = pd.DataFrame(Min.reshape(1,8), columns=[c+'_Min' for c in cols])
    Mean = pd.DataFrame(Mean.reshape(1,8), columns=[c+'_Mean' for c in cols])
    Std = pd.DataFrame(Std.reshape(1,8), columns=[c+'_Std' for c in cols])
    RMS = pd.DataFrame(RMS.reshape(1,8), columns=[c+'_RMS' for c in cols])
    Skewness = pd.DataFrame(Skewness.reshape(1,8), columns=[c+'_Skewness' for c in cols])
    Kurtosis = pd.DataFrame(Kurtosis.reshape(1,8), columns=[c+'_Kurtosis' for c in cols])
    Crestfactor = pd.DataFrame(Crestfactor.reshape(1,8), columns=[c+'_Crestfactor' for c in cols])
    Formfactor = pd.DataFrame(Formfactor.reshape(1,8), columns=[c+'_Formfactor' for c in cols])
    
    
    Max.index = [file_name]
    Min.index = [file_name]
    Mean.index = [file_name]
    Std.index = [file_name]
    RMS.index = [file_name]
    Skewness.index = [file_name]
    Kurtosis.index = [file_name]
    Crestfactor.index = [file_name]
    Formfactor.index = [file_name]
    
    merge = pd.concat([Max,Min,Mean,Std,RMS,Skewness,Kurtosis,Crestfactor,Formfactor], axis = 1)
    
    data=data.append(merge)
# Out:
# C:\Users\Saranya.Sakkarapani\Anaconda3\envs\anomaly_detection\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\Users\Saranya.Sakkarapani\Anaconda3\envs\anomaly_detection\lib\site-packages\numpy\core\fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# C:\Users\Saranya.Sakkarapani\AppData\Local\Temp\ipykernel_8036\10307651.py:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(merge)
# ...

# %%
data
# Out:
#                      1_a_Max  1_a_Min  1_a_Mean   1_a_Std   1_a_RMS  \
# 2003.10.22.12.06.13    0.388   -0.720 -0.094596  0.081124  0.124617
# 2003.10.22.12.09.13    0.388   -0.654 -0.094902  0.079519  0.123812
# 2003.10.22.12.14.13    0.317   -0.623 -0.096189  0.080220  0.125249
# 2003.10.22.12.19.13    0.457   -0.598 -0.095615  0.080828  0.125200
# 2003.10.22.12.24.13    0.388   -0.623 -0.095135  0.082038  0.125621
# ...                      ...      ...       ...       ...       ...
# 2003.11.25.16.07.32    0.476   -0.669 -0.117541  0.120934  0.168642
# 2003.11.25.23.13.21    0.513   -0.803 -0.117402  0.129748  0.174977
# 2003.11.25.23.19.56    0.449   -0.710 -0.118304  0.128376  0.174572
# 2003.11.25.23.29.56    0.522   -0.776 -0.118261  0.126898  0.173459
# 2003.11.25.23.39.56    0.630   -0.808 -0.117160  0.128898  0.174185
#
#                      1_a_Skewness  1_a_Kurtosis  1_a_Crestfactor  \
# 2003.10.22.12.06.13     -0.029896      1.068848         3.113546
# ...

# %%
data.index = pd.to_datetime(data.index, format='%Y.%m.%d.%H.%M.%S')
data = data.sort_index()

# %%
data
# Out:
#                      1_a_Max  1_a_Min  1_a_Mean   1_a_Std   1_a_RMS  \
# 2003-10-22 12:06:13    0.388   -0.720 -0.094596  0.081124  0.124617
# 2003-10-22 12:09:13    0.388   -0.654 -0.094902  0.079519  0.123812
# 2003-10-22 12:14:13    0.317   -0.623 -0.096189  0.080220  0.125249
# 2003-10-22 12:19:13    0.457   -0.598 -0.095615  0.080828  0.125200
# 2003-10-22 12:24:13    0.388   -0.623 -0.095135  0.082038  0.125621
# ...                      ...      ...       ...       ...       ...
# 2003-11-25 16:07:32    0.476   -0.669 -0.117541  0.120934  0.168642
# 2003-11-25 23:13:21    0.513   -0.803 -0.117402  0.129748  0.174977
# 2003-11-25 23:19:56    0.449   -0.710 -0.118304  0.128376  0.174572
# 2003-11-25 23:29:56    0.522   -0.776 -0.118261  0.126898  0.173459
# 2003-11-25 23:39:56    0.630   -0.808 -0.117160  0.128898  0.174185
#
#                      1_a_Skewness  1_a_Kurtosis  1_a_Crestfactor  \
# 2003-10-22 12:06:13     -0.029896      1.068848         3.113546
# ...

# %%
# merge a and b from bearing 1-4
data['1_Max'] = (data['1_a_Max'] + data['1_b_Max'])/2
data['1_Min'] = (data['1_a_Min'] + data['1_b_Min'])/2
data['1_Mean'] = (data['1_a_Mean'] + data['1_b_Mean'])/2
data['1_Std'] = (data['1_a_Std'] + data['1_b_Std'])/2
data['1_RMS'] = (data['1_a_RMS'] + data['1_b_RMS'])/2
data['1_Skewness'] = (data['1_a_Skewness'] + data['1_b_Skewness'])/2
data['1_Kurtosis'] = (data['1_a_Kurtosis'] + data['1_b_Kurtosis'])/2
data['1_Crestfactor'] = (data['1_a_Crestfactor'] + data['1_b_Crestfactor'])/2
data['1_Formfactor'] = (data['1_a_Formfactor'] + data['1_b_Formfactor'])/2

data['2_Max'] = (data['2_a_Max'] + data['2_b_Max'])/2
data['2_Min'] = (data['2_a_Min'] + data['2_b_Min'])/2
data['2_Mean'] = (data['2_a_Mean'] + data['2_b_Mean'])/2
data['2_Std'] = (data['2_a_Std'] + data['2_b_Std'])/2
data['2_RMS'] = (data['2_a_RMS'] + data['2_b_RMS'])/2
data['2_Skewness'] = (data['2_a_Skewness'] + data['2_b_Skewness'])/2
data['2_Kurtosis'] = (data['2_a_Kurtosis'] + data['2_b_Kurtosis'])/2
data['2_Crestfactor'] = (data['2_a_Crestfactor'] + data['2_b_Crestfactor'])/2
data['2_Formfactor'] = (data['2_a_Formfactor'] + data['2_b_Formfactor'])/2

data['3_Max'] = (data['3_a_Max'] + data['3_b_Max'])/2
data['3_Min'] = (data['3_a_Min'] + data['3_b_Min'])/2
data['3_Mean'] = (data['3_a_Mean'] + data['3_b_Mean'])/2
data['3_Std'] = (data['3_a_Std'] + data['3_b_Std'])/2
data['3_RMS'] = (data['3_a_RMS'] + data['3_b_RMS'])/2
data['3_Skewness'] = (data['3_a_Skewness'] + data['3_b_Skewness'])/2
data['3_Kurtosis'] = (data['3_a_Kurtosis'] + data['3_b_Kurtosis'])/2
data['3_Crestfactor'] = (data['3_a_Crestfactor'] + data['3_b_Crestfactor'])/2
data['3_Formfactor'] = (data['3_a_Formfactor'] + data['3_b_Formfactor'])/2

data['4_Max'] = (data['4_a_Max'] + data['4_b_Max'])/2
data['4_Min'] = (data['4_a_Min'] + data['4_b_Min'])/2
data['4_Mean'] = (data['4_a_Mean'] + data['4_b_Mean'])/2
data['4_Std'] = (data['4_a_Std'] + data['4_b_Std'])/2
data['4_RMS'] = (data['4_a_RMS'] + data['4_b_RMS'])/2
data['4_Skewness'] = (data['4_a_Skewness'] + data['4_b_Skewness'])/2
data['4_Kurtosis'] = (data['4_a_Kurtosis'] + data['4_b_Kurtosis'])/2
data['4_Crestfactor'] = (data['4_a_Crestfactor'] + data['4_b_Crestfactor'])/2
data['4_Formfactor'] = (data['4_a_Formfactor'] + data['4_b_Formfactor'])/2

data = data[['1_Max','1_Min','1_Mean','1_Std','1_RMS','1_Skewness','1_Kurtosis','1_Crestfactor','1_Formfactor',
             '2_Max','2_Min','2_Mean','2_Std','2_RMS','2_Skewness','2_Kurtosis','2_Crestfactor','2_Formfactor',
             '3_Max','3_Min','3_Mean','3_Std','3_RMS','3_Skewness','3_Kurtosis','3_Crestfactor','3_Formfactor',
             '4_Max','4_Min','4_Mean','4_Std','4_RMS','4_Skewness','4_Kurtosis','4_Crestfactor','4_Formfactor']]
data.head()
# Out:
#                       1_Max   1_Min    1_Mean     1_Std     1_RMS  1_Skewness  \
# 2003-10-22 12:06:13  0.5445 -0.6420 -0.094240  0.075888  0.121056    0.095150
# 2003-10-22 12:09:13  0.4845 -0.5725 -0.094397  0.074526  0.120323    0.028208
# 2003-10-22 12:14:13  0.4330 -0.5460 -0.096027  0.074843  0.121818    0.054776
# 2003-10-22 12:19:13  0.4960 -0.5360 -0.095462  0.076048  0.122104    0.052409
# 2003-10-22 12:24:13  0.3870 -0.5800 -0.095312  0.077093  0.122650    0.017957
#
#                      1_Kurtosis  1_Crestfactor  1_Formfactor   2_Max  ...  \
# 2003-10-22 12:06:13    2.067108       4.539861     -1.284433  0.3075  ...
# 2003-10-22 12:09:13    1.580649       4.053328     -1.274489  0.2665  ...
# 2003-10-22 12:14:13    1.477128       3.584151     -1.268523  0.3125  ...
# 2003-10-22 12:19:13    1.389413       4.072842     -1.279029  0.2650  ...
# 2003-10-22 12:24:13    1.145527       3.156974     -1.286894  0.3075  ...
#
# ...

# %%
data1 = data[['1_Max','1_Min','1_Mean','1_Std','1_RMS','1_Skewness','1_Kurtosis','1_Crestfactor','1_Formfactor']]

# %%
data1
# Out:
#                       1_Max   1_Min    1_Mean     1_Std     1_RMS  1_Skewness  \
# 2003-10-22 12:06:13  0.5445 -0.6420 -0.094240  0.075888  0.121056    0.095150
# 2003-10-22 12:09:13  0.4845 -0.5725 -0.094397  0.074526  0.120323    0.028208
# 2003-10-22 12:14:13  0.4330 -0.5460 -0.096027  0.074843  0.121818    0.054776
# 2003-10-22 12:19:13  0.4960 -0.5360 -0.095462  0.076048  0.122104    0.052409
# 2003-10-22 12:24:13  0.3870 -0.5800 -0.095312  0.077093  0.122650    0.017957
# ...                     ...     ...       ...       ...       ...         ...
# 2003-11-25 16:07:32  0.4835 -0.6285 -0.117679  0.110586  0.161664    0.032343
# 2003-11-25 23:13:21  0.5850 -0.7130 -0.116973  0.118003  0.166344    0.000369
# 2003-11-25 23:19:56  0.5065 -0.6625 -0.117725  0.116677  0.165936   -0.021398
# 2003-11-25 23:29:56  0.5795 -0.7105 -0.118583  0.116506  0.166413    0.012122
# 2003-11-25 23:39:56  0.5740 -0.7200 -0.116985  0.117642  0.166089    0.012731
#
# ...

# %%
df1 = data1.rename(columns={'1_Max':'Max','1_Min':'Min','1_Mean':'Mean','1_Std':'Std','1_RMS':'RMS','1_Skewness':'Skewness','1_Kurtosis':'Kurtosis','1_Crestfactor':'Crestfactor','1_Formfactor':'Formfactor'})

# %%
df1.columns
# Out:
# Index(['Max', 'Min', 'Mean', 'Std', 'RMS', 'Skewness', 'Kurtosis',
#        'Crestfactor', 'Formfactor'],
#       dtype='object')

# %%
df1
# Out:
#                         Max     Min      Mean       Std       RMS  Skewness  \
# 2003-10-22 12:06:13  0.5445 -0.6420 -0.094240  0.075888  0.121056  0.095150
# 2003-10-22 12:09:13  0.4845 -0.5725 -0.094397  0.074526  0.120323  0.028208
# 2003-10-22 12:14:13  0.4330 -0.5460 -0.096027  0.074843  0.121818  0.054776
# 2003-10-22 12:19:13  0.4960 -0.5360 -0.095462  0.076048  0.122104  0.052409
# 2003-10-22 12:24:13  0.3870 -0.5800 -0.095312  0.077093  0.122650  0.017957
# ...                     ...     ...       ...       ...       ...       ...
# 2003-11-25 16:07:32  0.4835 -0.6285 -0.117679  0.110586  0.161664  0.032343
# 2003-11-25 23:13:21  0.5850 -0.7130 -0.116973  0.118003  0.166344  0.000369
# 2003-11-25 23:19:56  0.5065 -0.6625 -0.117725  0.116677  0.165936 -0.021398
# 2003-11-25 23:29:56  0.5795 -0.7105 -0.118583  0.116506  0.166413  0.012122
# 2003-11-25 23:39:56  0.5740 -0.7200 -0.116985  0.117642  0.166089  0.012731
#
#                      Kurtosis  Crestfactor  Formfactor
# ...

# %%
test_set = 1
bearing_no = 1
df1.to_csv('Time_feature_matrix_bearing_{}_Test_ {}.csv'.format(bearing_no,test_set))
